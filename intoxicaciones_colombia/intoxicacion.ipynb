# %% [markdown]
# ## Analisis del dataset de intoxicaciones

# %%
import pandas as pd; import numpy as np; import matplotlib.pyplot as plt; import seaborn as sns

df = pd.read_csv('intoxicaciones.csv')

# %%
df
# Out:
#       orden  cod_eve                         grupo fecha notificacion  \
# 0         1      365  FACTORES DE RIESGO AMBIENTAL         21/12/2014
# 1         2      365  FACTORES DE RIESGO AMBIENTAL         26/12/2014
# 2         3      365  FACTORES DE RIESGO AMBIENTAL         18/12/2014
# 3         4      365  FACTORES DE RIESGO AMBIENTAL         23/12/2014
# 4         5      365  FACTORES DE RIESGO AMBIENTAL         25/12/2014
# ...     ...      ...                           ...                ...
# 1630   1631      365  FACTORES DE RIESGO AMBIENTAL         10/10/2022
# 1631   1632      365  FACTORES DE RIESGO AMBIENTAL         10/10/2022
# 1632   1633      365  FACTORES DE RIESGO AMBIENTAL         10/10/2022
# 1633   1634      365  FACTORES DE RIESGO AMBIENTAL         15/10/2022
# 1634   1635      365  FACTORES DE RIESGO AMBIENTAL         15/10/2022
#
#       semana epidemiológica  año epidemiológica     cod_pre  cod_sub  edad  \
# ...
